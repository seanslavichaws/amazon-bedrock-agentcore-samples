# %% [markdown]
# # Hosting LlamaIndex Agents with Amazon Bedrock models in Amazon Bedrock AgentCore Runtime with Observability
#
# ## Overview
#
# In this tutorial we will learn how to host your LlamaIndex agent using Amazon Bedrock AgentCore Runtime with built-in observability. This tutorial demonstrates how to deploy a LlamaIndex agent to AgentCore Runtime and automatically capture telemetry data for monitoring and analysis.
#
# ### Tutorial Details
#
# | Information         | Details                                                                          |
# |:--------------------|:---------------------------------------------------------------------------------|
# | Tutorial type       | Conversational                                                                   |
# | Agent type          | Single                                                                           |
# | Agentic Framework   | LlamaIndex                                                                       |
# | LLM model           | Anthropic Claude Haiku                                                           |
# | Tutorial components | Hosting agent on AgentCore Runtime with Observability                           |
# | Tutorial vertical   | Cross-vertical                                                                   |
# | Example complexity  | Easy                                                                             |
# | SDK used            | Amazon BedrockAgentCore Python SDK and boto3                                    |
#
# ### Tutorial Architecture
#
# In this tutorial we will describe how to deploy a LlamaIndex agent to AgentCore runtime with automatic observability.
#
# For demonstration purposes, we will use a LlamaIndex FunctionAgent using Amazon Bedrock models with arithmetic tools.
#
# ### Tutorial Key Features
#
# * Hosting LlamaIndex Agents on Amazon Bedrock AgentCore Runtime
# * Using Amazon Bedrock models
# * Automatic observability and tracing
# * Built-in telemetry collection

# %% [markdown]
# ## Prerequisites
#
# To execute this tutorial you will need:
# * Python 3.10+
# * AWS credentials
# * Amazon Bedrock AgentCore SDK
# * LlamaIndex
# * Amazon Bedrock Model access to Claude Haiku

# %% [markdown]
# ### In Your Terminal:
#
# `cd 01-tutorials/06-AgentCore-observability/01-Agentcore-runtime-hosted/LlamaIndex`
#
# `python -m venv venv`
#
# `source venv/bin/activate`
#
# ### In Your Notebook:
#
# Select your venv as your kernel

# %%
# !pip install -q --force-reinstall -U -r requirements.txt
# Out:
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Creating your LlamaIndex agent and experimenting locally
#
# Before we deploy our agent to AgentCore Runtime, let's develop and run it locally for experimentation purposes.
#
# For production agentic applications we will need to decouple the agent creation process from the agent invocation one. With AgentCore Runtime, we will decorate the invocation part of our agent with the `@app.entrypoint` decorator and have it as the entry point for our runtime.

# %%
# %%writefile llamaindex_agent.py

import warnings
warnings.filterwarnings("ignore", message=".*validate_default.*", category=UserWarning)
import os
import json
import argparse
import boto3
from llama_index.llms.bedrock_converse import BedrockConverse
from llama_index.core.agent.workflow import FunctionAgent
from llama_index.observability.otel import LlamaIndexOpenTelemetry


# Initialize OpenTelemetry instrumentation for LlamaIndex
instrumentor = LlamaIndexOpenTelemetry()
# Start listening
instrumentor.start_registering()

def multiply(a: int, b: int) -> int:
    """Multiple two integers and returns the result integer"""
    return a * b

def add(a: int, b: int) -> int:
    """Add two integers and returns the result integer"""
    return a + b

def get_bedrock_model():
    model_id = "anthropic.claude-3-5-haiku-20241022-v1:0"
    region = boto3.Session().region_name
    
    bedrock_model = BedrockConverse(
        model=model_id,
        region_name=region,
    )
    return bedrock_model

# Initialize the model
bedrock_model = get_bedrock_model()

# Create the arithmetic agent
agent = FunctionAgent(
    tools=[add, multiply],
    llm=bedrock_model,
)

async def llamaindex_agent_bedrock(payload):
    """
    Invoke the agent with a payload
    """
    user_input = payload.get("prompt")
    response = await agent.run(user_input)
    return str(response)

if __name__ == "__main__":
    import asyncio
    parser = argparse.ArgumentParser()
    parser.add_argument("payload", type=str)
    args = parser.parse_args()
    response = asyncio.run(llamaindex_agent_bedrock(json.loads(args.payload)))
    print(response)
# Out:
# Overwriting llamaindex_agent.py

# %% [markdown]
# #### Invoking local agent

# %%
# !python llamaindex_agent.py '{"prompt": "What is (121 + 2) * 5?"}'
# Out:
# {
#     "name": "FunctionAgent.init_run-bec8e08e-da7e-41a8-8af5-d4d47c97f734",
#     "context": {
#         "trace_id": "0xdaef3eb4efebc355b54b5403df5e57a8",
#         "span_id": "0xcb9b5063f40ef422",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0x8c8f86788f4229af",
#     "start_time": "2025-12-22T03:06:50.759478Z",
#     "end_time": "2025-12-22T03:06:50.830850Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {},
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "service.name": "llamaindex.opentelemetry"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "FunctionAgent.setup_agent-78dbf34e-f58d-4e8f-88de-72add7a36343",
#     "context": {
#         "trace_id": "0xdaef3eb4efebc355b54b5403df5e57a8",
#         "span_id": "0xd1e6965a6f409b0e",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0x8c8f86788f4229af",
#     "start_time": "2025-12-22T03:06:50.831548Z",
#     "end_time": "2025-12-22T03:06:50.831586Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {},
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "service.name": "llamaindex.opentelemetry"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "BedrockConverse._prepare_chat_with_tools-e50b043f-460c-4304-b572-4d303830d1ab",
#     "context": {
#         "trace_id": "0xdaef3eb4efebc355b54b5403df5e57a8",
#         "span_id": "0x452d297ff0730dbc",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0xdcacb38a3d72b4d8",
#     "start_time": "2025-12-22T03:06:50.832081Z",
#     "end_time": "2025-12-22T03:06:50.841208Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {},
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "service.name": "llamaindex.opentelemetry"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "BedrockConverse.astream_chat-2c3d08c9-4ce5-4349-9a37-0769cf6ba490",
#     "context": {
#         "trace_id": "0xdaef3eb4efebc355b54b5403df5e57a8",
#         "span_id": "0x38fc3070ecd3e6a9",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0xdcacb38a3d72b4d8",
#     "start_time": "2025-12-22T03:06:50.841317Z",
#     "end_time": "2025-12-22T03:06:50.841625Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {},
#     "events": [
#         {
#             "name": "LLMChatStartEvent",
#             "timestamp": "2025-12-22T03:06:50.841618Z",
#             "attributes": {
#                 "id_": "a852784c-fab2-446e-b1ef-c1305dac0b70",
#                 "span_id": "BedrockConverse.astream_chat-2c3d08c9-4ce5-4349-9a37-0769cf6ba490",
#                 "class_name": "LLMChatStartEvent"
#             }
#         }
#     ],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "service.name": "llamaindex.opentelemetry"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "FunctionAgent.run_agent_step-8af535fc-03b2-4c8b-9034-e66e670a23d6",
#     "context": {
#         "trace_id": "0xdaef3eb4efebc355b54b5403df5e57a8",
#         "span_id": "0xdcacb38a3d72b4d8",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0x8c8f86788f4229af",
#     "start_time": "2025-12-22T03:06:50.831856Z",
#     "end_time": "2025-12-22T03:06:53.276840Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {},
#     "events": [
#         {
#             "name": "LLMChatInProgressEvent",
#             "timestamp": "2025-12-22T03:06:53.276780Z",
#             "attributes": {
#                 "id_": "6a314a60-5c79-4b05-b178-a748421149e6",
#                 "span_id": "BedrockConverse.astream_chat-2c3d08c9-4ce5-4349-9a37-0769cf6ba490",
#                 "class_name": "LLMChatInProgressEvent"
#             }
#         },
#         {
#             "name": "LLMChatInProgressEvent",
#             "timestamp": "2025-12-22T03:06:53.276791Z",
#             "attributes": {
#                 "id_": "ab73c29e-667e-4a29-bfa2-9b0fb6126325",
#                 "span_id": "BedrockConverse.astream_chat-2c3d08c9-4ce5-4349-9a37-0769cf6ba490",
#                 "class_name": "LLMChatInProgressEvent"
#             }
#         },
#         {
#             "name": "LLMChatInProgressEvent",
#             "timestamp": "2025-12-22T03:06:53.276796Z",
#             "attributes": {
#                 "id_": "0720b149-fcc6-4f93-97b3-6f87fdd2b9f4",
#                 "span_id": "BedrockConverse.astream_chat-2c3d08c9-4ce5-4349-9a37-0769cf6ba490",
#                 "class_name": "LLMChatInProgressEvent"
#             }
#         },
#         {
#             "name": "LLMChatInProgressEvent",
#             "timestamp": "2025-12-22T03:06:53.276799Z",
#             "attributes": {
#                 "id_": "f241967a-f526-4e7c-a36d-5ec9f2e4094b",
#                 "span_id": "BedrockConverse.astream_chat-2c3d08c9-4ce5-4349-9a37-0769cf6ba490",
#                 "class_name": "LLMChatInProgressEvent"
#             }
#         },
#         {
#             "name": "LLMChatInProgressEvent",
#             "timestamp": "2025-12-22T03:06:53.276803Z",
#             "attributes": {
#                 "id_": "aee3aa20-23b2-49b7-b921-c704cdd66722",
#                 "span_id": "BedrockConverse.astream_chat-2c3d08c9-4ce5-4349-9a37-0769cf6ba490",
#                 "class_name": "LLMChatInProgressEvent"
#             }
#         },
#         {
#             "name": "LLMChatInProgressEvent",
#             "timestamp": "2025-12-22T03:06:53.276807Z",
#             "attributes": {
#                 "id_": "2f68010c-407b-45ec-81d7-e279420bd903",
#                 "span_id": "BedrockConverse.astream_chat-2c3d08c9-4ce5-4349-9a37-0769cf6ba490",
#                 "class_name": "LLMChatInProgressEvent"
#             }
#         },
#         {
#             "name": "LLMChatInProgressEvent",
#             "timestamp": "2025-12-22T03:06:53.276810Z",
#             "attributes": {
#                 "id_": "8525e7b8-ec9a-4732-8f68-a51738adaa1e",
#                 "span_id": "BedrockConverse.astream_chat-2c3d08c9-4ce5-4349-9a37-0769cf6ba490",
#                 "class_name": "LLMChatInProgressEvent"
#             }
#         },
#         {
#             "name": "LLMChatInProgressEvent",
#             "timestamp": "2025-12-22T03:06:53.276814Z",
#             "attributes": {
#                 "id_": "0b35dc3d-1f47-49a0-846c-f442b1e267b2",
#                 "span_id": "BedrockConverse.astream_chat-2c3d08c9-4ce5-4349-9a37-0769cf6ba490",
#                 "class_name": "LLMChatInProgressEvent"
#             }
#         },
#         {
#             "name": "LLMChatInProgressEvent",
#             "timestamp": "2025-12-22T03:06:53.276818Z",
#             "attributes": {
#                 "id_": "958f886d-4f18-414e-b847-87f4d14a47f2",
#                 "span_id": "BedrockConverse.astream_chat-2c3d08c9-4ce5-4349-9a37-0769cf6ba490",
#                 "class_name": "LLMChatInProgressEvent"
#             }
#         },
#         {
#             "name": "LLMChatInProgressEvent",
#             "timestamp": "2025-12-22T03:06:53.276821Z",
#             "attributes": {
#                 "id_": "7b61d6a1-44d9-4578-b8ee-d434d8d5ad87",
#                 "span_id": "BedrockConverse.astream_chat-2c3d08c9-4ce5-4349-9a37-0769cf6ba490",
#                 "class_name": "LLMChatInProgressEvent"
#             }
#         },
#         {
#             "name": "LLMChatInProgressEvent",
#             "timestamp": "2025-12-22T03:06:53.276824Z",
#             "attributes": {
#                 "id_": "9b289565-61fe-4b4e-bd76-9f673a98b102",
#                 "span_id": "BedrockConverse.astream_chat-2c3d08c9-4ce5-4349-9a37-0769cf6ba490",
#                 "class_name": "LLMChatInProgressEvent"
#             }
#         },
#         {
#             "name": "LLMChatInProgressEvent",
#             "timestamp": "2025-12-22T03:06:53.276828Z",
#             "attributes": {
#                 "id_": "e0ad207a-8674-4a72-910d-8179df7c1457",
#                 "span_id": "BedrockConverse.astream_chat-2c3d08c9-4ce5-4349-9a37-0769cf6ba490",
#                 "class_name": "LLMChatInProgressEvent"
#             }
#         },
#         {
#             "name": "LLMChatInProgressEvent",
#             "timestamp": "2025-12-22T03:06:53.276831Z",
#             "attributes": {
#                 "id_": "47de658a-a6ad-4b01-91dc-4ebc46513a2e",
#                 "span_id": "BedrockConverse.astream_chat-2c3d08c9-4ce5-4349-9a37-0769cf6ba490",
#                 "class_name": "LLMChatInProgressEvent"
#             }
#         },
#         {
#             "name": "LLMChatEndEvent",
#             "timestamp": "2025-12-22T03:06:53.276834Z",
#             "attributes": {
#                 "id_": "05767dbd-9c8d-4f0b-af13-6e473d70fdb7",
#                 "span_id": "BedrockConverse.astream_chat-2c3d08c9-4ce5-4349-9a37-0769cf6ba490",
#                 "class_name": "LLMChatEndEvent"
#             }
#         }
#     ],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "service.name": "llamaindex.opentelemetry"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "FunctionAgent.parse_agent_output-8abb3dd5-ca11-40f4-b702-5b3d87c4cf86",
#     "context": {
#         "trace_id": "0xdaef3eb4efebc355b54b5403df5e57a8",
#         "span_id": "0x613022bc1d4beeff",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0x8c8f86788f4229af",
#     "start_time": "2025-12-22T03:06:53.277425Z",
#     "end_time": "2025-12-22T03:06:53.277500Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {},
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "service.name": "llamaindex.opentelemetry"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "FunctionTool.acall-fcdfdebb-e883-44d3-8d9c-ad9d36b588e3",
#     "context": {
#         "trace_id": "0xdaef3eb4efebc355b54b5403df5e57a8",
#         "span_id": "0x08921aac6518d2a9",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0xfd5db51da8642885",
#     "start_time": "2025-12-22T03:06:53.277988Z",
#     "end_time": "2025-12-22T03:06:53.278173Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {},
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "service.name": "llamaindex.opentelemetry"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "FunctionAgent.call_tool-5068e79d-0f56-4884-a0e1-7cbc35862949",
#     "context": {
#         "trace_id": "0xdaef3eb4efebc355b54b5403df5e57a8",
#         "span_id": "0xfd5db51da8642885",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0x8c8f86788f4229af",
#     "start_time": "2025-12-22T03:06:53.277901Z",
#     "end_time": "2025-12-22T03:06:53.278223Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {},
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "service.name": "llamaindex.opentelemetry"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "FunctionAgent.aggregate_tool_results-44a10de6-3be9-48fc-bde6-24e8ac49b554",
#     "context": {
#         "trace_id": "0xdaef3eb4efebc355b54b5403df5e57a8",
#         "span_id": "0x122284d5b8e4e2f5",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0x8c8f86788f4229af",
#     "start_time": "2025-12-22T03:06:53.278587Z",
#     "end_time": "2025-12-22T03:06:53.278864Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {},
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "service.name": "llamaindex.opentelemetry"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "FunctionAgent.setup_agent-ed24ab69-51b0-4c64-9d11-434d711143b8",
#     "context": {
#         "trace_id": "0xdaef3eb4efebc355b54b5403df5e57a8",
#         "span_id": "0x6fc7fc42080a60da",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0x8c8f86788f4229af",
#     "start_time": "2025-12-22T03:06:53.279170Z",
#     "end_time": "2025-12-22T03:06:53.279209Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {},
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "service.name": "llamaindex.opentelemetry"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "BedrockConverse._prepare_chat_with_tools-3aeb61cd-7e3c-46d8-9854-65a900d68270",
#     "context": {
#         "trace_id": "0xdaef3eb4efebc355b54b5403df5e57a8",
#         "span_id": "0x31a756b1d7e3edc4",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0x3189c19e178e33cd",
#     "start_time": "2025-12-22T03:06:53.279623Z",
#     "end_time": "2025-12-22T03:06:53.279981Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {},
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "service.name": "llamaindex.opentelemetry"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "BedrockConverse.astream_chat-4ee50347-ed02-49b7-bdf4-fcf460f7ea6e",
#     "context": {
#         "trace_id": "0xdaef3eb4efebc355b54b5403df5e57a8",
#         "span_id": "0x844c8e1bfd135c6b",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0x3189c19e178e33cd",
#     "start_time": "2025-12-22T03:06:53.280048Z",
#     "end_time": "2025-12-22T03:06:53.280324Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {},
#     "events": [
#         {
#             "name": "LLMChatStartEvent",
#             "timestamp": "2025-12-22T03:06:53.280320Z",
#             "attributes": {
#                 "id_": "834db7d9-859d-4b52-a56d-7ad460d31f9d",
#                 "span_id": "BedrockConverse.astream_chat-4ee50347-ed02-49b7-bdf4-fcf460f7ea6e",
#                 "class_name": "LLMChatStartEvent"
#             }
#         }
#     ],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "service.name": "llamaindex.opentelemetry"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "FunctionAgent.run_agent_step-8314c107-eaff-4dc8-9536-2bb76a2251bd",
#     "context": {
#         "trace_id": "0xdaef3eb4efebc355b54b5403df5e57a8",
#         "span_id": "0x3189c19e178e33cd",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0x8c8f86788f4229af",
#     "start_time": "2025-12-22T03:06:53.279497Z",
#     "end_time": "2025-12-22T03:06:55.021493Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {},
#     "events": [
#         {
#             "name": "LLMChatInProgressEvent",
#             "timestamp": "2025-12-22T03:06:55.021421Z",
#             "attributes": {
#                 "id_": "b0346a74-f2a1-4676-8b8a-ab4d2ec591ed",
#                 "span_id": "BedrockConverse.astream_chat-4ee50347-ed02-49b7-bdf4-fcf460f7ea6e",
#                 "class_name": "LLMChatInProgressEvent"
#             }
#         },
#         {
#             "name": "LLMChatInProgressEvent",
#             "timestamp": "2025-12-22T03:06:55.021434Z",
#             "attributes": {
#                 "id_": "4c5476f9-e32a-41e1-ba62-e2e76e961492",
#                 "span_id": "BedrockConverse.astream_chat-4ee50347-ed02-49b7-bdf4-fcf460f7ea6e",
#                 "class_name": "LLMChatInProgressEvent"
#             }
#         },
#         {
#             "name": "LLMChatInProgressEvent",
#             "timestamp": "2025-12-22T03:06:55.021441Z",
#             "attributes": {
#                 "id_": "84d6732d-c9d5-4e7c-9373-3a62162589eb",
#                 "span_id": "BedrockConverse.astream_chat-4ee50347-ed02-49b7-bdf4-fcf460f7ea6e",
#                 "class_name": "LLMChatInProgressEvent"
#             }
#         },
#         {
#             "name": "LLMChatInProgressEvent",
#             "timestamp": "2025-12-22T03:06:55.021447Z",
#             "attributes": {
#                 "id_": "89f4dc9b-fb84-4954-8f0c-18a8a5db5386",
#                 "span_id": "BedrockConverse.astream_chat-4ee50347-ed02-49b7-bdf4-fcf460f7ea6e",
#                 "class_name": "LLMChatInProgressEvent"
#             }
#         },
#         {
#             "name": "LLMChatInProgressEvent",
#             "timestamp": "2025-12-22T03:06:55.021453Z",
#             "attributes": {
#                 "id_": "623a75c8-c304-4dd1-9609-8866339c10e0",
#                 "span_id": "BedrockConverse.astream_chat-4ee50347-ed02-49b7-bdf4-fcf460f7ea6e",
#                 "class_name": "LLMChatInProgressEvent"
#             }
#         },
#         {
#             "name": "LLMChatInProgressEvent",
#             "timestamp": "2025-12-22T03:06:55.021459Z",
#             "attributes": {
#                 "id_": "8297614d-bf99-4a02-ade1-67440856e6ea",
#                 "span_id": "BedrockConverse.astream_chat-4ee50347-ed02-49b7-bdf4-fcf460f7ea6e",
#                 "class_name": "LLMChatInProgressEvent"
#             }
#         },
#         {
#             "name": "LLMChatInProgressEvent",
#             "timestamp": "2025-12-22T03:06:55.021465Z",
#             "attributes": {
#                 "id_": "1ce054bd-2f38-4d1f-b19a-18e139cb4185",
#                 "span_id": "BedrockConverse.astream_chat-4ee50347-ed02-49b7-bdf4-fcf460f7ea6e",
#                 "class_name": "LLMChatInProgressEvent"
#             }
#         },
#         {
#             "name": "LLMChatInProgressEvent",
#             "timestamp": "2025-12-22T03:06:55.021470Z",
#             "attributes": {
#                 "id_": "5b369422-35ea-4050-9a91-7af87bd1a333",
#                 "span_id": "BedrockConverse.astream_chat-4ee50347-ed02-49b7-bdf4-fcf460f7ea6e",
#                 "class_name": "LLMChatInProgressEvent"
#             }
#         },
#         {
#             "name": "LLMChatInProgressEvent",
#             "timestamp": "2025-12-22T03:06:55.021476Z",
#             "attributes": {
#                 "id_": "b3b1fe7b-1812-4602-84b9-579c07cfa73e",
#                 "span_id": "BedrockConverse.astream_chat-4ee50347-ed02-49b7-bdf4-fcf460f7ea6e",
#                 "class_name": "LLMChatInProgressEvent"
#             }
#         },
#         {
#             "name": "LLMChatEndEvent",
#             "timestamp": "2025-12-22T03:06:55.021482Z",
#             "attributes": {
#                 "id_": "473d03ae-e48f-49db-8b52-9382e85ce6bb",
#                 "span_id": "BedrockConverse.astream_chat-4ee50347-ed02-49b7-bdf4-fcf460f7ea6e",
#                 "class_name": "LLMChatEndEvent"
#             }
#         }
#     ],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "service.name": "llamaindex.opentelemetry"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "FunctionAgent.parse_agent_output-f1d33811-5fed-4e8e-8990-e161c98696c3",
#     "context": {
#         "trace_id": "0xdaef3eb4efebc355b54b5403df5e57a8",
#         "span_id": "0x2e48d906978ec3a2",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0x8c8f86788f4229af",
#     "start_time": "2025-12-22T03:06:55.022615Z",
#     "end_time": "2025-12-22T03:06:55.022844Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {},
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "service.name": "llamaindex.opentelemetry"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "FunctionTool.acall-be702103-0a98-48e0-adaf-e4bb4e35db15",
#     "context": {
#         "trace_id": "0xdaef3eb4efebc355b54b5403df5e57a8",
#         "span_id": "0x72db610cf519ed9d",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0xe5507d3f7bbb9794",
#     "start_time": "2025-12-22T03:06:55.023906Z",
#     "end_time": "2025-12-22T03:06:55.024149Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {},
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "service.name": "llamaindex.opentelemetry"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "FunctionAgent.call_tool-ec1b01ec-793f-4bdd-a638-1a5b94fed322",
#     "context": {
#         "trace_id": "0xdaef3eb4efebc355b54b5403df5e57a8",
#         "span_id": "0xe5507d3f7bbb9794",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0x8c8f86788f4229af",
#     "start_time": "2025-12-22T03:06:55.023757Z",
#     "end_time": "2025-12-22T03:06:55.024206Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {},
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "service.name": "llamaindex.opentelemetry"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "FunctionAgent.aggregate_tool_results-0b2964c5-e4ef-4153-add6-4b2d02d066b5",
#     "context": {
#         "trace_id": "0xdaef3eb4efebc355b54b5403df5e57a8",
#         "span_id": "0x9e90e2b30d50a8d9",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0x8c8f86788f4229af",
#     "start_time": "2025-12-22T03:06:55.024766Z",
#     "end_time": "2025-12-22T03:06:55.025223Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {},
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "service.name": "llamaindex.opentelemetry"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "FunctionAgent.setup_agent-5c06f678-5501-442f-9762-6043e65c8ed2",
#     "context": {
#         "trace_id": "0xdaef3eb4efebc355b54b5403df5e57a8",
#         "span_id": "0x7ffd618334724a33",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0x8c8f86788f4229af",
#     "start_time": "2025-12-22T03:06:55.025886Z",
#     "end_time": "2025-12-22T03:06:55.025962Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {},
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "service.name": "llamaindex.opentelemetry"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "BedrockConverse._prepare_chat_with_tools-94a6cf8f-c7af-4abe-9421-1d0148e0ef6b",
#     "context": {
#         "trace_id": "0xdaef3eb4efebc355b54b5403df5e57a8",
#         "span_id": "0x339196c8083bd17d",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0x871febcb151e2e36",
#     "start_time": "2025-12-22T03:06:55.026709Z",
#     "end_time": "2025-12-22T03:06:55.027273Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {},
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "service.name": "llamaindex.opentelemetry"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "BedrockConverse.astream_chat-d2ba2d69-40b4-4d8d-b289-b83ceeb0c7e8",
#     "context": {
#         "trace_id": "0xdaef3eb4efebc355b54b5403df5e57a8",
#         "span_id": "0x8c19f032581ee0d1",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0x871febcb151e2e36",
#     "start_time": "2025-12-22T03:06:55.027368Z",
#     "end_time": "2025-12-22T03:06:55.027790Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {},
#     "events": [
#         {
#             "name": "LLMChatStartEvent",
#             "timestamp": "2025-12-22T03:06:55.027783Z",
#             "attributes": {
#                 "id_": "ca0aa5c1-b3aa-4545-beb9-68c301bbccd8",
#                 "span_id": "BedrockConverse.astream_chat-d2ba2d69-40b4-4d8d-b289-b83ceeb0c7e8",
#                 "class_name": "LLMChatStartEvent"
#             }
#         }
#     ],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "service.name": "llamaindex.opentelemetry"
#         },
#         "schema_url": ""
#     }
# }
# So, (121 + 2) * 5 = 615.
# {
#     "name": "FunctionAgent.run_agent_step-67338dba-fc31-446c-8ad2-73ffc5a17604",
#     "context": {
#         "trace_id": "0xdaef3eb4efebc355b54b5403df5e57a8",
#         "span_id": "0x871febcb151e2e36",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0x8c8f86788f4229af",
#     "start_time": "2025-12-22T03:06:55.026492Z",
#     "end_time": "2025-12-22T03:06:56.294139Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {},
#     "events": [
#         {
#             "name": "LLMChatInProgressEvent",
#             "timestamp": "2025-12-22T03:06:56.294087Z",
#             "attributes": {
#                 "id_": "cdab0a69-9b96-4b97-ae1a-e6c758db123d",
#                 "span_id": "BedrockConverse.astream_chat-d2ba2d69-40b4-4d8d-b289-b83ceeb0c7e8",
#                 "class_name": "LLMChatInProgressEvent"
#             }
#         },
#         {
#             "name": "LLMChatInProgressEvent",
#             "timestamp": "2025-12-22T03:06:56.294103Z",
#             "attributes": {
#                 "id_": "ad41735e-22dc-4efa-9394-22f52617b24b",
#                 "span_id": "BedrockConverse.astream_chat-d2ba2d69-40b4-4d8d-b289-b83ceeb0c7e8",
#                 "class_name": "LLMChatInProgressEvent"
#             }
#         },
#         {
#             "name": "LLMChatInProgressEvent",
#             "timestamp": "2025-12-22T03:06:56.294111Z",
#             "attributes": {
#                 "id_": "efedf9ae-8c98-4a92-9dc2-6f6ce84bca0b",
#                 "span_id": "BedrockConverse.astream_chat-d2ba2d69-40b4-4d8d-b289-b83ceeb0c7e8",
#                 "class_name": "LLMChatInProgressEvent"
#             }
#         },
#         {
#             "name": "LLMChatInProgressEvent",
#             "timestamp": "2025-12-22T03:06:56.294117Z",
#             "attributes": {
#                 "id_": "2bc4e171-5e45-4eef-b09d-a7c046afe8f9",
#                 "span_id": "BedrockConverse.astream_chat-d2ba2d69-40b4-4d8d-b289-b83ceeb0c7e8",
#                 "class_name": "LLMChatInProgressEvent"
#             }
#         },
#         {
#             "name": "LLMChatEndEvent",
#             "timestamp": "2025-12-22T03:06:56.294124Z",
#             "attributes": {
#                 "id_": "eb850397-7a1f-4e4f-98ab-a6cdb4805bf8",
#                 "span_id": "BedrockConverse.astream_chat-d2ba2d69-40b4-4d8d-b289-b83ceeb0c7e8",
#                 "class_name": "LLMChatEndEvent"
#             }
#         }
#     ],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "service.name": "llamaindex.opentelemetry"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "FunctionAgent.parse_agent_output-a285fdad-9711-402a-9b79-533837eb850f",
#     "context": {
#         "trace_id": "0xdaef3eb4efebc355b54b5403df5e57a8",
#         "span_id": "0x7433ae8f293c91d1",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": "0x8c8f86788f4229af",
#     "start_time": "2025-12-22T03:06:56.295662Z",
#     "end_time": "2025-12-22T03:06:56.297057Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {},
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "service.name": "llamaindex.opentelemetry"
#         },
#         "schema_url": ""
#     }
# }
# {
#     "name": "FunctionAgent.run-00ba5133-3e1d-4bde-b14e-77d0509d522f",
#     "context": {
#         "trace_id": "0xdaef3eb4efebc355b54b5403df5e57a8",
#         "span_id": "0x8c8f86788f4229af",
#         "trace_state": "[]"
#     },
#     "kind": "SpanKind.INTERNAL",
#     "parent_id": null,
#     "start_time": "2025-12-22T03:06:50.758359Z",
#     "end_time": "2025-12-22T03:06:56.297403Z",
#     "status": {
#         "status_code": "OK"
#     },
#     "attributes": {},
#     "events": [],
#     "links": [],
#     "resource": {
#         "attributes": {
#             "service.name": "llamaindex.opentelemetry"
#         },
#         "schema_url": ""
#     }
# }

# %% [markdown]
# ## Preparing your agent for deployment on AgentCore Runtime
#
# Let's now deploy our agent to AgentCore Runtime. To do so we need to:
# * Import the Runtime App with `from bedrock_agentcore.runtime import BedrockAgentCoreApp`
# * Initialize the App in our code with `app = BedrockAgentCoreApp()`
# * Decorate the invocation function with the `@app.entrypoint` decorator
# * Let AgentCoreRuntime control the running of the agent with `app.run()`
#
# ### LlamaIndex Agent with Amazon Bedrock model
# Let's prepare our LlamaIndex Agent for AgentCore Runtime deployment.

# %%
# %%writefile llamaindex_agent.py

import warnings
warnings.filterwarnings("ignore", message=".*validate_default.*", category=UserWarning)
import os
import json
import boto3
from bedrock_agentcore.runtime import BedrockAgentCoreApp
from llama_index.llms.bedrock_converse import BedrockConverse
from llama_index.core.agent.workflow import FunctionAgent
from llama_index.observability.otel import LlamaIndexOpenTelemetry


app = BedrockAgentCoreApp()

# Initialize OpenTelemetry instrumentation for LlamaIndex
instrumentor = LlamaIndexOpenTelemetry(debug=True)
# Start listening
instrumentor.start_registering()

def multiply(a: int, b: int) -> int:
    """Multiple two integers and returns the result integer"""
    return a * b

def add(a: int, b: int) -> int:
    """Add two integers and returns the result integer"""
    return a + b

def get_bedrock_model():
    model_id = "anthropic.claude-3-5-haiku-20241022-v1:0"
    region = boto3.Session().region_name
    
    bedrock_model = BedrockConverse(
        model=model_id,
        region_name=region,
    )
    return bedrock_model

# Initialize the model
bedrock_model = get_bedrock_model()

# Create the arithmetic agent
agent = FunctionAgent(
    tools=[add, multiply],
    llm=bedrock_model,
)

@app.entrypoint
async def llamaindex_agent_bedrock(payload):
    """
    Invoke the agent with a payload
    """
    user_input = payload.get("prompt")
    print("User input:", user_input)
    response = await agent.run(user_input)
    return str(response)

if __name__ == "__main__":
    app.run()
# Out:
# Overwriting llamaindex_agent.py

# %% [markdown]
# ## What happens behind the scenes?
#
# When you use `BedrockAgentCoreApp`, it automatically:
#
# * Creates an HTTP server that listens on the port 8080
# * Implements the required `/invocations` endpoint for processing the agent's requirements
# * Implements the `/ping` endpoint for health checks
# * Handles proper content types and response formats
# * Manages error handling according to the AWS standards
# * **Automatically enables observability and telemetry collection**

# %% [markdown]
# ## Deploying the agent to AgentCore Runtime
#
# The `CreateAgentRuntime` operation supports comprehensive configuration options, letting you specify container images, environment variables and encryption settings. You can also configure protocol settings (HTTP, MCP) and authorization mechanisms to control how your clients communicate with the agent.
#
# **Note:** Operations best practice is to package code as container and push to ECR using CI/CD pipelines and IaC
#
# In this tutorial we will use the Amazon Bedrock AgentCore Python SDK to easily package your artifacts and deploy them to AgentCore runtime.

# %% [markdown]
# ### Configure AgentCore Runtime deployment
#
# First we will use our starter toolkit to configure the AgentCore Runtime deployment with an entrypoint, the execution role we just created and a requirements file. We will also configure the starter kit to auto create the Amazon ECR repository on launch.
#
# During the configure step, your docker file will be generated based on your application code

# %%
from bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore import Runtime
from boto3.session import Session
boto_session = Session()
region = boto_session.region_name

agentcore_runtime = Runtime()
agent_name = "llamaindex_bedrock_getting_started10"
response = agentcore_runtime.configure(
    entrypoint="llamaindex_agent.py",
    auto_create_execution_role=True,
    auto_create_ecr=True,
    requirements_file="requirements.txt",
    region=region,
    agent_name=agent_name
)
response
# Out:
# Entrypoint parsed: file=/Users/sslavich/amazon-bedrock-agentcore-samples/01-tutorials/06-AgentCore-observability/01-Agentcore-runtime-hosted/LlamaIndex/llamaindex_agent.py, bedrock_agentcore_name=llamaindex_agent
# Configuring BedrockAgentCore agent: llamaindex_bedrock_getting_started10
# ⚠️  ℹ️  No container engine found (Docker/Finch/Podman not installed)
# ✅ Default deployment uses CodeBuild (no container engine needed)
# 💡 Run 'agentcore launch' for cloud-based building and deployment
# 💡 For local builds, install Docker, Finch, or Podman
# Generated Dockerfile: /Users/sslavich/amazon-bedrock-agentcore-samples/01-tutorials/06-AgentCore-observability/01-Agentcore-runtime-hosted/LlamaIndex/Dockerfile
# Generated .dockerignore: /Users/sslavich/amazon-bedrock-agentcore-samples/01-tutorials/06-AgentCore-observability/01-Agentcore-runtime-hosted/LlamaIndex/.dockerignore
# Changing default agent from 'llamaindex_bedrock_getting_started09' to 'llamaindex_bedrock_getting_started10'
# Bedrock AgentCore configured: /Users/sslavich/amazon-bedrock-agentcore-samples/01-tutorials/06-AgentCore-observability/01-Agentcore-runtime-hosted/LlamaIndex/.bedrock_agentcore.yaml
# ConfigureResult(config_path=PosixPath('/Users/sslavich/amazon-bedrock-agentcore-samples/01-tutorials/06-AgentCore-observability/01-Agentcore-runtime-hosted/LlamaIndex/.bedrock_agentcore.yaml'), dockerfile_path=PosixPath('/Users/sslavich/amazon-bedrock-agentcore-samples/01-tutorials/06-AgentCore-observability/01-Agentcore-runtime-hosted/LlamaIndex/Dockerfile'), dockerignore_path=PosixPath('/Users/sslavich/amazon-bedrock-agentcore-samples/01-tutorials/06-AgentCore-observability/01-Agentcore-runtime-hosted/LlamaIndex/.dockerignore'), runtime='None', region='us-west-2', account_id='276716987786', execution_role=None, ecr_repository=None, auto_create_ecr=True)

# %% [markdown]
# ### Launching agent to AgentCore Runtime
#
# Now that we've got a docker file, let's launch the agent to the AgentCore Runtime. This will create the Amazon ECR repository and the AgentCore Runtime with observability automatically enabled. You can add libraries to the environment variable below to exclude unnecessary traces from specific libraries.

# %%
launch_result = agentcore_runtime.launch(
    env_vars={
        # Minimal set - only disable truly noisy instrumentations
        "OTEL_PYTHON_DISABLED_INSTRUMENTATIONS": (
            "jinja2,"
            "urllib3,"
            "requests,"
            "httpx,"
            "redis,"
            "aiohttp-client"
            # Add "starlette" to this list to get rid of the POST /invocations trace. Note: this will disable session tracking.
        )
    }
)
# Out:
# 🚀 CodeBuild mode: building in cloud (RECOMMENDED - DEFAULT)
#    • Build ARM64 containers in the cloud with CodeBuild
#    • No local Docker required
# 💡 Available deployment modes:
#    • runtime.launch()                           → CodeBuild (current)
#    • runtime.launch(local=True)                 → Local development
#    • runtime.launch(local_build=True)           → Local build + cloud deploy (NEW)
# Starting CodeBuild ARM64 deployment for agent 'llamaindex_bedrock_getting_started10' to account 276716987786 (us-west-2)
# Setting up AWS resources (ECR repository, execution roles)...
# Getting or creating ECR repository for agent: llamaindex_bedrock_getting_started10
# Repository doesn't exist, creating new ECR repository: bedrock-agentcore-llamaindex_bedrock_getting_started10
# ✅ ECR repository available: 276716987786.dkr.ecr.us-west-2.amazonaws.com/bedrock-agentcore-llamaindex_bedrock_getting_started10
# Getting or creating execution role for agent: llamaindex_bedrock_getting_started10
# Using AWS region: us-west-2, account ID: 276716987786
# Role name: AmazonBedrockAgentCoreSDKRuntime-us-west-2-32ccc2406d
# Role doesn't exist, creating new execution role: AmazonBedrockAgentCoreSDKRuntime-us-west-2-32ccc2406d
# Starting execution role creation process for agent: llamaindex_bedrock_getting_started10
# ✓ Role creating: AmazonBedrockAgentCoreSDKRuntime-us-west-2-32ccc2406d
# Creating IAM role: AmazonBedrockAgentCoreSDKRuntime-us-west-2-32ccc2406d
# ✓ Role created: arn:aws:iam::276716987786:role/AmazonBedrockAgentCoreSDKRuntime-us-west-2-32ccc2406d
# ✓ Execution policy attached: BedrockAgentCoreRuntimeExecutionPolicy-llamaindex_bedrock_getting_started10
# Role creation complete and ready for use with Bedrock AgentCore
# ✅ Execution role available: arn:aws:iam::276716987786:role/AmazonBedrockAgentCoreSDKRuntime-us-west-2-32ccc2406d
# Preparing CodeBuild project and uploading source...
# Getting or creating CodeBuild execution role for agent: llamaindex_bedrock_getting_started10
# Role name: AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-32ccc2406d
# CodeBuild role doesn't exist, creating new role: AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-32ccc2406d
# Creating IAM role: AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-32ccc2406d
# ✓ Role created: arn:aws:iam::276716987786:role/AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-32ccc2406d
# Attaching inline policy: CodeBuildExecutionPolicy to role: AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-32ccc2406d
# ✓ Policy attached: CodeBuildExecutionPolicy
# Waiting for IAM role propagation...
# CodeBuild execution role creation complete: arn:aws:iam::276716987786:role/AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-32ccc2406d
# Using .dockerignore with 44 patterns
# Uploaded source to S3: llamaindex_bedrock_getting_started10/source.zip
# Created CodeBuild project: bedrock-agentcore-llamaindex_bedrock_getting_started10-builder
# Starting CodeBuild build (this may take several minutes)...
# Starting CodeBuild monitoring...
# 🔄 QUEUED started (total: 0s)
# ✅ QUEUED completed in 1.1s
# 🔄 PROVISIONING started (total: 1s)
# ✅ PROVISIONING completed in 8.7s
# 🔄 DOWNLOAD_SOURCE started (total: 10s)
# ✅ DOWNLOAD_SOURCE completed in 2.2s
# 🔄 BUILD started (total: 12s)
# ✅ BUILD completed in 25.1s
# 🔄 POST_BUILD started (total: 37s)
# ✅ POST_BUILD completed in 18.5s
# 🔄 COMPLETED started (total: 56s)
# ✅ COMPLETED completed in 1.1s
# 🎉 CodeBuild completed successfully in 0m 56s
# CodeBuild completed successfully
# ✅ CodeBuild project configuration saved
# Deploying to Bedrock AgentCore...
# ✅ Agent created/updated: arn:aws:bedrock-agentcore:us-west-2:276716987786:runtime/llamaindex_bedrock_getting_started10-YduR7G8jvj
# Observability is enabled, configuring Transaction Search...
# CloudWatch Logs resource policy already configured
# X-Ray trace destination already configured
# X-Ray indexing rule already configured
# ✅ Transaction Search already fully configured
# 🔍 GenAI Observability Dashboard:
#    https://console.aws.amazon.com/cloudwatch/home?region=us-west-2#gen-ai-observability/agent-core
# Polling for endpoint to be ready...
# Agent endpoint: arn:aws:bedrock-agentcore:us-west-2:276716987786:runtime/llamaindex_bedrock_getting_started10-YduR7G8jvj/runtime-endpoint/DEFAULT
# Deployment completed successfully - Agent: arn:aws:bedrock-agentcore:us-west-2:276716987786:runtime/llamaindex_bedrock_getting_started10-YduR7G8jvj
# Built with CodeBuild: bedrock-agentcore-llamaindex_bedrock_getting_started10-builder:c7a8e765-53f1-4d69-b361-61cc5014072c
# Deployed to cloud: arn:aws:bedrock-agentcore:us-west-2:276716987786:runtime/llamaindex_bedrock_getting_started10-YduR7G8jvj
# ECR image: 276716987786.dkr.ecr.us-west-2.amazonaws.com/bedrock-agentcore-llamaindex_bedrock_getting_started10
# 🔍 Agent logs available at:
#    /aws/bedrock-agentcore/runtimes/llamaindex_bedrock_getting_started10-YduR7G8jvj-DEFAULT --log-stream-name-prefix "2025/12/22/\[runtime-logs]"
#    /aws/bedrock-agentcore/runtimes/llamaindex_bedrock_getting_started10-YduR7G8jvj-DEFAULT --log-stream-names "otel-rt-logs"
# 💡 Tail logs with: aws logs tail /aws/bedrock-agentcore/runtimes/llamaindex_bedrock_getting_started10-YduR7G8jvj-DEFAULT --log-stream-name-prefix "2025/12/22/\[runtime-logs]" --follow
# 💡 Or view recent logs: aws logs tail /aws/bedrock-agentcore/runtimes/llamaindex_bedrock_getting_started10-YduR7G8jvj-DEFAULT --log-stream-name-prefix "2025/12/22/\[runtime-logs]" --since 1h

# %% [markdown]
# ### Checking for the AgentCore Runtime Status
# Now that we've deployed the AgentCore Runtime, let's check for its deployment status

# %%
import time
status_response = agentcore_runtime.status()
status = status_response.endpoint['status']
end_status = ['READY', 'CREATE_FAILED', 'DELETE_FAILED', 'UPDATE_FAILED']
while status not in end_status:
    time.sleep(10)
    status_response = agentcore_runtime.status()
    status = status_response.endpoint['status']
    print(status)
status
# Out:
# Retrieved Bedrock AgentCore status for: llamaindex_bedrock_getting_started10
# 'READY'

# %% [markdown]
# ## Enable Tracing for your AgentCore Runtime
#
# In your AWS console, navigate to Amazon Bedrock AgentCore. Click on Agent Runtime under Build and Deploy and select your agent.
#
# For your agent, scroll until you see the Tracing section. Enable this to allow for trace delivery to CloudWatch:
#
# ![enable_tracing.png](images/llamaindex_enable_tracing.png)

# %% [markdown]
# ### Invoking AgentCore Runtime
#
# Finally, we can invoke our AgentCore Runtime with a payload. This will automatically generate telemetry data that can be viewed in the observability dashboard.

# %%
invoke_response = agentcore_runtime.invoke({"prompt": "What is (121 + 2) * 5?"})
invoke_response
# Out:
# {'ResponseMetadata': {'RequestId': '1302f0be-c9d3-4e45-9eca-a71c61cf92c7',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Mon, 22 Dec 2025 03:19:59 GMT',
#    'content-type': 'application/json',
#    'transfer-encoding': 'chunked',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': '1302f0be-c9d3-4e45-9eca-a71c61cf92c7',
#    'baggage': 'Self=1-6948b8cd-6169cd4d3e04a75164598a73,session.id=d805f353-51be-457d-b485-8fd45be67843',
#    'x-amzn-bedrock-agentcore-runtime-session-id': 'd805f353-51be-457d-b485-8fd45be67843',
#    'x-amzn-trace-id': 'Root=1-6948b8cd-31504eed724778733f66b5b8;Parent=fa2703b122b318e3;Sampled=1;Self=1-6948b8cd-6169cd4d3e04a75164598a73'},
#   'RetryAttempts': 0},
#  'runtimeSessionId': 'd805f353-51be-457d-b485-8fd45be67843',
#  'traceId': 'Root=1-6948b8cd-31504eed724778733f66b5b8;Parent=fa2703b122b318e3;Sampled=1;Self=1-6948b8cd-6169cd4d3e04a75164598a73',
#  'baggage': 'Self=1-6948b8cd-6169cd4d3e04a75164598a73,session.id=d805f353-51be-457d-b485-8fd45be67843',
#  'contentType': 'application/json',
#  'statusCode': 200,
#  'response': ['So, (121 + 2) * 5 = 615.']}

# %% [markdown]
# ### Processing invocation results
#
# We can now process our invocation results to include it in an application

# %%
from IPython.display import Markdown, display
import json
response_text = invoke_response['response'][0]
display(Markdown(response_text))
# Out:
# So, (121 + 2) * 5 = 615.

# %% [markdown]
# ### Invoking AgentCore Runtime with boto3
#
# Now that your AgentCore Runtime was created you can invoke it with any AWS SDK. For instance, you can use the boto3 `invoke_agent_runtime` method for it.

# %%
import boto3
agent_arn = launch_result.agent_arn
agentcore_client = boto3.client(
    'bedrock-agentcore',
    region_name=region
)

boto3_response = agentcore_client.invoke_agent_runtime(
    agentRuntimeArn=agent_arn,
    qualifier="DEFAULT",
    payload=json.dumps({"prompt": "What is 15 * 8?"})
)
if "text/event-stream" in boto3_response.get("contentType", ""):
    content = []
    for line in boto3_response["response"].iter_lines(chunk_size=1):
        if line:
            line = line.decode("utf-8")
            if line.startswith("data: "):
                line = line[6:]
                print(line)
                content.append(line)
    display(Markdown("\n".join(content)))
else:
    try:
        events = []
        for event in boto3_response.get("response", []):
            events.append(event)
    except Exception as e:
        events = [f"Error reading EventStream: {e}"]
    display(Markdown(json.loads(events[0].decode("utf-8"))))
# Out:
# ---------------------------------------------------------------------------
# RuntimeClientError                        Traceback (most recent call last)
# Cell In[14], line 8
#       2 agent_arn = launch_result.agent_arn
#       3 agentcore_client = boto3.client(
#       4     'bedrock-agentcore',
#       5     region_name=region
#       6 )
# ----> 8 boto3_response = agentcore_client.invoke_agent_runtime(
#       9     agentRuntimeArn=agent_arn,
#      10     qualifier="DEFAULT",
#      11     payload=json.dumps({"prompt": "What is 15 * 8?"})
#      12 )
#      13 if "text/event-stream" in boto3_response.get("contentType", ""):
#      14     content = []
#
# File ~/amazon-bedrock-agentcore-samples/venv/lib/python3.13/site-packages/botocore/client.py:602, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     598     raise TypeError(
#     599         f"{py_operation_name}() only accepts keyword arguments."
#     600     )
#     601 # The "self" in this scope is referring to the BaseClient.
# --> 602 return self._make_api_call(operation_name, kwargs)
#
# File ~/amazon-bedrock-agentcore-samples/venv/lib/python3.13/site-packages/botocore/context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File ~/amazon-bedrock-agentcore-samples/venv/lib/python3.13/site-packages/botocore/client.py:1078, in BaseClient._make_api_call(self, operation_name, api_params)
#    1074     error_code = request_context.get(
#    1075         'error_code_override'
#    1076     ) or error_info.get("Code")
#    1077     error_class = self.exceptions.from_code(error_code)
# -> 1078     raise error_class(parsed_response, operation_name)
#    1079 else:
#    1080     return parsed_response
#
# RuntimeClientError: An error occurred (RuntimeClientError) when calling the InvokeAgentRuntime operation: Received error (500) from runtime. Please check your CloudWatch logs for more information.

# %% [markdown]
# ## Observability Dashboard
#
# ### Automatic Telemetry Collection
#
# When your LlamaIndex agent runs on AgentCore Runtime, telemetry data is automatically collected and sent to Amazon CloudWatch. This includes:
#
# - **Agent execution traces**: Complete workflow of your agent's decision-making process
# - **LLM calls**: Bedrock model invocations with input/output tokens
# - **Tool usage**: Function calls and their results
# - **Performance metrics**: Latency, token usage, and error rates
#
# ### Viewing Traces in CloudWatch
#
# To view your agent's observability data:
#
# 1. Navigate to the AWS CloudWatch console
# 2. Go to **GenAI Observability** dashboard
# 3. Select your agent runtime to view traces and metrics
#
# ### Key Observability Features
#
# - **Session tracking**: Correlate multiple interactions
# - **Error monitoring**: Identify and debug issues
# - **Performance analysis**: Optimize agent response times

# %% [markdown]
# ### AgentCore Observability on Amazon CloudWatch
#
# To summarize, please follow the below steps to enable observability from AgentCore runtime hosted agents:
#
# - Enable Transaction Search on Amazon CloudWatch
# - The requirements.txt file contains `aws-opentelemetry-distro` listed while deploying the agent on Bedrock AgentCore Runtime.
#
# ## Bedrock AgentCore Overview on GenAI Observability dashboard
#
# You are able to view all your Agents that have observability in them and filter the data based on time frames, some examples are provided below:
#
# ![genai-observability.png](images/llamaindex_dashboard_view.png)
#
# In the main dashboard you are able to view runtime metrics across all agents as shown below:
#
# ![runtime-all-agent-metrics.png](images/llamaindex_runtime_metrics_total_view.png)
#
# Now, if you click on the agent you just deployed you will be taken to a dashboard for the runtime metrics specific to this agent, you can also filter the data by a custom time frame:
#
# ![runtime-metrics-per-agent.png](images/llamaindex_runtime_metrics_view.png)
#
# In the Sessions View tab, you can navigate to all the sessions associated with this agent:
#
# ![Agent-sessions-view.png](images/llamaindex_sessions_view.png)
#
# In the Trace View tab, you can look into the traces and span information for this agent on runtime:
#
# ![Agentcore-trace.png](images/llamaindex_traces_view.png)
#
# Please click through the various features of GenAI observability dashboard to get more detailed information on traces.

# %% [markdown]
# ## Cleanup (Optional)
#
# Let's now clean up the AgentCore Runtime created

# %%
launch_result.ecr_uri, launch_result.agent_id, launch_result.ecr_uri.split('/')[1]

# %%
import boto3
agentcore_control_client = boto3.client(
    'bedrock-agentcore-control',
    region_name=region
)
ecr_client = boto3.client(
    'ecr',
    region_name=region
    
)

runtime_delete_response = agentcore_control_client.delete_agent_runtime(
    agentRuntimeId=launch_result.agent_id,
    
)

response = ecr_client.delete_repository(
    repositoryName=launch_result.ecr_uri.split('/')[1],
    force=True
)

# %% [markdown]
# # Congratulations!
#
# You have successfully:
#
# - Created a LlamaIndex agent with arithmetic tools
# - Deployed it to Amazon Bedrock AgentCore Runtime
# - Enabled automatic observability and telemetry collection
# - Invoked the agent and generated trace data
#
# Your agent is now running with full observability capabilities, allowing you to monitor performance, debug issues, and optimize your agentic applications.
